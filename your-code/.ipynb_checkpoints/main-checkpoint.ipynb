# %% [markdown]
# # Pandas Deep-Dive
#
# #### 1. Import Pandas package under the alias pd and Numpy under the alias np.

# %%
# your code here
import pandas as pd
import numpy as np

# %% [markdown]
# #### 2. Define a variable called `path` that contains the path to the csv file you downloaded. If you are reading the data from Ironhack's database, define the variables needed to create the connection with the database.

# %%
# your code here
path=r'C:\Users\amohedasgonzalez\Downloads\0.Ironhack\Modulo 1 - semana 10\lab-pandas-deep-dive\your-code'

# %% [markdown]
# #### 3. Using the pandas, read the data either from the downladed file or the database.
#
# Assign the returned value to a variable called `data`.

# %%
# your code here
data=pd.read_csv('apple_store.csv')
data
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 2      281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# ...          ...                                                ...
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      100788224   3.99             21292                26          4.0
# ...

# %% [markdown]
# #### 4. Print the first 5 rows of `data` to see what the data look like.
#
# A data analyst usually does this to have a general understanding about what the data look like before digging deep.

# %%
# your code here
data_5rows=data.head()
data_5rows

#Option 2:
#data_5rows=data.loc[0:4,:]
#data_5rows
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0   3.99             21292                26          4.0              4.5
# 1   0.00            161065                26          4.0              3.5
# 2   0.00            188583              2822          3.5              4.5
# 3   0.00            262241               649          4.0              4.5
# 4   0.00            985920              5320          4.5              5.0
#
#     prime_genre
# 0         Games
# 1  Productivity
# ...

# %% [markdown]
# #### 5. Print the summary of the data.

# %%
# your code here

data.describe()

#data.info()
# Out:
#                  id    size_bytes        price  rating_count_tot  \
# count  7.197000e+03  7.197000e+03  7197.000000      7.197000e+03
# mean   8.631310e+08  1.991345e+08     1.726218      1.289291e+04
# std    2.712368e+08  3.592069e+08     5.833006      7.573941e+04
# min    2.816565e+08  5.898240e+05     0.000000      0.000000e+00
# 25%    6.000937e+08  4.692275e+07     0.000000      2.800000e+01
# 50%    9.781482e+08  9.715302e+07     0.000000      3.000000e+02
# 75%    1.082310e+09  1.819249e+08     1.990000      2.793000e+03
# max    1.188376e+09  4.025970e+09   299.990000      2.974676e+06
#
#        rating_count_ver  user_rating  user_rating_ver
# count       7197.000000  7197.000000      7197.000000
# mean         460.373906     3.526956         3.253578
# std         3920.455183     1.517948         1.809363
# min            0.000000     0.000000         0.000000
# 25%            1.000000     3.500000         2.500000
# 50%           23.000000     4.000000         4.000000
# ...

# %% [markdown]
# #### 6. Print the number of columns in the data.

# %%
# your code here

#Option 1:
columns=len(data.columns)
columns

#Option 2:
columns=data.shape[1]
columns
# Out:
# 9

# %% [markdown]
# #### 7. Print all column names.

# %%
# your code here

data.columns
# Out:
# Index(['id', 'track_name', 'size_bytes', 'price', 'rating_count_tot',
#        'rating_count_ver', 'user_rating', 'user_rating_ver', 'prime_genre'],
#       dtype='object')

# %% [markdown]
# #### 8.- Now that we have a general understanding of the data, we'll start working on the challenge questions. How many apps are there in the data source? Print the number of observations of the data.
#
# **Hint**: Your code should return the number 7197.

# %%
# your code here

len(data['track_name'])
# Out:
# 7197

# %% [markdown]
# #### 9. What is the average rating of all apps?
#
# First, read the `user_rating` column into a varialbe named `user_rating`.

# %%
# your code here

#Reading user_rating columns and printing the output:
user_rating=data['user_rating']
print(user_rating)
# Out:
# 0       4.0
# 1       4.0
# 2       3.5
# 3       4.0
# 4       4.5
#        ...
# 7192    4.5
# 7193    4.5
# 7194    4.5
# 7195    4.5
# 7196    5.0
# Name: user_rating, Length: 7197, dtype: float64
# 3.526955675976101

# %% [markdown]
# Now you can calculate the average of the `user_rating` data.
#
# **Hint**: Your code should return 3.526955675976101.

# %%
# your code here

#Calculate the mean:
user_rating_average=user_rating.mean()
user_rating_average
# Out:
# 3.526955675976101

# %% [markdown]
# #### 10. How many apps have an average rating no less than 4?
#
# First, filter `user_rating` where its value >= 4.
#
# Assign the filtered dataframe to a new variable called `user_rating_high`.

# %%
# your code here

user_rating_high=data[data['user_rating']>=4]
user_rating_high
# Out:
#               id                                         track_name  \
# 0      281656475                                    PAC-MAN Premium
# 1      281796108                          Evernote - stay organized
# 3      282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4      282935706                                              Bible
# 5      283619399                                   Shanghai Mahjong
# ...          ...                                                ...
# 7192  1187617475                                              Kubik
# 7193  1187682390                                  VR Roller-Coaster
# 7194  1187779532              Bret Michaels Emojis + Lyric Keyboard
# 7195  1187838770          VR Roller Coaster World - Virtual Reality
# 7196  1188375727                       Escape the Sweet Shop Series
#
#       size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      100788224   3.99             21292                26          4.0
# ...

# %% [markdown]
# Now obtain the length of `user_rating_high` which should return 4781.

# %%
# your code here
len(user_rating_high)
# Out:
# 4781

# %% [markdown]
# #### 11. How many genres are there in total for all the apps?
#
# Define a new variable named `genres` that contains the `prime_genre` column of `data`. Google for how to obtain unique values of a dataframe column.

# %%
# your code here

genres=data['prime_genre'].unique()
genres
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %% [markdown]
# Print the length of the unique values of `genres`. Your code should return 23.

# %%
# your code here

genres_len=data['prime_genre'].nunique()
genres_len
# Out:
# 23

# %% [markdown]
# #### 12. What are the top 3 genres that have the most number of apps?
#
# What you want to do is to count the number of occurrences of each unique genre values. Because you already know how to obtain the unique genre values, you can of course count the # of apps of each genre one by one. However, Pandas has a convient function to let you count all values of a dataframe column with a single command. Google for "pandas count values" to find the solution. Your code should return the following:
#
# ```
# Games            3862
# Entertainment     535
# Education         453
# Name: prime_genre, dtype: int64
# ```

# %%
# your code here

data['prime_genre'].value_counts()
data['prime_genre'].value_counts().head(3)
# Out:
# Games            3862
# Entertainment     535
# Education         453
# Name: prime_genre, dtype: int64

# %% [markdown]
# #### 13. Which genre is most likely to contain free apps?
#
# First, filter `data` where the price is 0.00. Assign the filtered data to a new variable called `free_apps`. Then count the values in `free_apps`. Your code should return:
#
# ```
# Games                2257
# Entertainment         334
# Photo & Video         167
# Social Networking     143
# Education             132
# Shopping              121
# Utilities             109
# Lifestyle              94
# Finance                84
# Sports                 79
# Health & Fitness       76
# Music                  67
# Book                   66
# Productivity           62
# News                   58
# Travel                 56
# Food & Drink           43
# Weather                31
# Navigation             20
# Reference              20
# Business               20
# Catalogs                9
# Medical                 8
# Name: prime_genre, dtype: int64
# ```

# %%
# your code here

free_apps=data[data['price'] == 0]
free_apps['prime_genre'].value_counts()
free_apps['prime_genre'].value_counts().head(1)
# Out:
# Games    2257
# Name: prime_genre, dtype: int64

# %% [markdown]
# #### 14. Now you can calculate the proportion of the free apps in each genre based on the value counts you obtained in the previous two steps.
#
# Challenge yourself by achieving that with one line of code. The output should look like:
#
# ```
# Shopping             0.991803
# Catalogs             0.900000
# Social Networking    0.856287
# Finance              0.807692
# News                 0.773333
# Sports               0.692982
# Travel               0.691358
# Food & Drink         0.682540
# Lifestyle            0.652778
# Entertainment        0.624299
# Book                 0.589286
# Games                0.584412
# Music                0.485507
# Photo & Video        0.478510
# Utilities            0.439516
# Navigation           0.434783
# Weather              0.430556
# Health & Fitness     0.422222
# Business             0.350877
# Productivity         0.348315
# Medical              0.347826
# Reference            0.312500
# Education            0.291391
# Name: prime_genre, dtype: float64
# ```
#
# The numbers are interesting, aren't they?

# %%
# your code here

data_proportion=free_apps['prime_genre'].value_counts()/data['prime_genre'].value_counts()
data_proportion.sort_values(ascending= False)
# Out:
# Shopping             0.991803
# Catalogs             0.900000
# Social Networking    0.856287
# Finance              0.807692
# News                 0.773333
# Sports               0.692982
# Travel               0.691358
# Food & Drink         0.682540
# Lifestyle            0.652778
# Entertainment        0.624299
# Book                 0.589286
# Games                0.584412
# Music                0.485507
# Photo & Video        0.478510
# Utilities            0.439516
# Navigation           0.434783
# Weather              0.430556
# Health & Fitness     0.422222
# Business             0.350877
# Productivity         0.348315
# Medical              0.347826
# Reference            0.312500
# Education            0.291391
# Name: prime_genre, dtype: float64

# %% [markdown]
# #### 15. If a developer tries to make money by developing and selling Apple Store apps, in which genre should s/he develop the apps? Please assume all apps cost the same amount of time and expense to develop.
#
# We will leave this question to you. There are several way to solve it. Ideally your output should look like below:
#
# ```
#     average_price              genre
# 21       8.776087            Medical
# 11       5.116316           Business
# 4        4.836875          Reference
# 6        4.835435              Music
# 1        4.330562       Productivity
# 15       4.124783         Navigation
# 16       4.028234          Education
# 12       1.916444   Health & Fitness
# 20       1.790536               Book
# 7        1.647621          Utilities
# 2        1.605417            Weather
# 18       1.552381       Food & Drink
# 14       1.473295      Photo & Video
# 0        1.432923              Games
# 8        1.120370             Travel
# 10       0.953070             Sports
# 13       0.889701      Entertainment
# 17       0.885417          Lifestyle
# 22       0.799000           Catalogs
# 19       0.517733               News
# 5        0.421154            Finance
# 9        0.339880  Social Networking
# 3        0.016311           Shopping
# ```

# %%
# your code here

#filter apps that are not free
data_not_free=data[data['price']>0]
data_not_free

#get the list of genres displaying the count of "not free" apps by genre and their mean:
gender_high_price=data_not_free.groupby(['prime_genre']).agg({'prime_genre':'count','price':'mean'})

#sort price column
gender_high_price.sort_values(by='price', ascending= False)

#The developer should focus on developing medical or music apps.
#It semms that with medical apps they would earn more money per app.
#Additionally, there are not too much competitors (only 15 apps).
# Out:
#                    prime_genre      price
# prime_genre
# Medical                     15  13.456667
# Music                       71   9.398451
# Catalogs                     1   7.990000
# Business                    37   7.881892
# Navigation                  26   7.297692
# Reference                   44   7.035455
# Productivity               116   6.645172
# Education                  321   5.684704
# Food & Drink                20   4.890000
# Book                        46   4.359565
# Travel                      25   3.630000
# Games                     1605   3.447944
# Health & Fitness           104   3.316923
# Sports                      35   3.104286
# Utilities                  139   2.939640
# Photo & Video              182   2.825165
# Weather                     41   2.819268
# Lifestyle                   50   2.550000
# Entertainment              201   2.368109
# Social Networking           24   2.365000
# News                        17   2.284118
# ...

# %% [markdown]
# # Challenge - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the head() function.

# %%
# Your code here:

pm25.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''

# Your code here:
def hourly(x):
    
        return x/24

# %% [markdown]
# Apply this function to the columns Iws, Is, and Ir. Store this new dataframe in the variable pm25_hourly.

# %%
# Your code here:

pm25_hourly=pm25[['Iws','Is','Ir']].apply(hourly)
pm25_hourly
# Out:
#              Iws   Is   Ir
# 0       0.074583  0.0  0.0
# 1       0.205000  0.0  0.0
# 2       0.279583  0.0  0.0
# 3       0.410000  0.0  0.0
# 4       0.540417  0.0  0.0
# ...          ...  ...  ...
# 43819   9.665417  0.0  0.0
# 43820   9.907500  0.0  0.0
# 43821  10.112500  0.0  0.0
# 43822  10.280000  0.0  0.0
# 43823  10.410417  0.0  0.0
#
# [43824 rows x 3 columns]

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
    
    total=np.std(x)/x.value_counts()
    return total-1

# %%
calculation=pm25[['Iws','TEMP']].apply(sample_sd)
calculation
# Out:
#                Iws      TEMP
# -19.00         NaN  5.099237
# -18.00         NaN  0.742639
# -17.00         NaN  0.016539
# -16.00         NaN -0.491730
# -15.00         NaN -0.716315
# ...            ...       ...
#  570.41  49.010064       NaN
#  573.54  49.010064       NaN
#  577.56  49.010064       NaN
#  581.58  49.010064       NaN
#  585.60  49.010064       NaN
#
# [2848 rows x 2 columns]
